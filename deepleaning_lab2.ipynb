# %% [markdown]
# <a href="https://colab.research.google.com/github/jingmingliu01/DeepLearning-DSCI-6011-01-25Fall/blob/main/deepleaning_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class NN(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear1 = nn.Linear(2,5,bias=True)
    self.linear2 = nn.Linear(5,3,bias=True)
    # ReLU already defined as function

  def forward(self,x):
    p=self.linear1.forward(x)
    h=F.relu(p)
    z=self.linear2.forward(h)
    return z

# %%
model = NN()

# %%
CELoss = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr=0.01)

# %%
class RandDataset(torch.utils.data.Dataset):
  def __init__(self,nSamples):
    super().__init__()
    self.X = torch.rand((nSamples,2))
    self.y = torch.randint(low=0,high=3,size=(nSamples,))

  def __len__(self):
    sz = self.X.shape[0]
    return sz

  def __getitem__(self,idx):
    sample = self.X[idx]
    label = self.y[idx]
    return sample,label

# %%
train_dataset = RandDataset(nSamples=100)
val_dataset = RandDataset(nSamples=20)

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset,batch_size=8,shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset,batch_size=8,shuffle=False)

# %%
best_val_acc = 0

for epoch in range(10):
  print("epoch",epoch)
  model.train()
  for batch in train_dataloader:
    samples, labels = batch
    print("sample size",samples.shape)
    zhat = model.forward(samples)
    loss = CELoss(zhat,labels)
    print("loss",loss.item())
    model.zero_grad()
    loss.backward()
    optimizer.step()

  model.eval()
  with torch.no_grad():
    correct = 0
    for batch in val_dataloader:
      samples, labels = batch
      zhat = model.forward(samples)
      loss = CELoss(zhat,labels)
      print("test loss",loss.item())
      pred_labels = torch.argmax(zhat,dim=1)
      correct += (pred_labels==labels).sum()
    val_acc = correct/len(val_dataset)
    print("val acc",val_acc)
    if val_acc > best_val_acc:
      best_val_acc = val_acc
      torch.save(model.state_dict(),"best_model.pt")
# Out:
# epoch 0
# sample size torch.Size([8, 2])
# loss 1.1084927320480347
# sample size torch.Size([8, 2])
# loss 1.0904924869537354
# sample size torch.Size([8, 2])
# loss 1.1054518222808838
# sample size torch.Size([8, 2])
# loss 1.0589953660964966
# sample size torch.Size([8, 2])
# loss 1.0734666585922241
# sample size torch.Size([8, 2])
# loss 1.0557841062545776
# sample size torch.Size([8, 2])
# loss 1.080081820487976
# sample size torch.Size([8, 2])
# loss 1.1085764169692993
# sample size torch.Size([8, 2])
# loss 1.0782756805419922
# sample size torch.Size([8, 2])
# loss 1.0352636575698853
# sample size torch.Size([8, 2])
# loss 1.0946829319000244
# sample size torch.Size([8, 2])
# loss 1.0967724323272705
# sample size torch.Size([4, 2])
# loss 1.1027653217315674
# test loss 1.1037178039550781
# test loss 1.1149903535842896
# test loss 1.1171094179153442
# val acc tensor(0.2500)
# epoch 1
# sample size torch.Size([8, 2])
# loss 1.0599502325057983
# sample size torch.Size([8, 2])
# loss 1.1195580959320068
# sample size torch.Size([8, 2])
# loss 1.0993709564208984
# sample size torch.Size([8, 2])
# loss 1.050972819328308
# sample size torch.Size([8, 2])
# loss 1.0257600545883179
# sample size torch.Size([8, 2])
# loss 1.127755045890808
# sample size torch.Size([8, 2])
# loss 1.105753779411316
# sample size torch.Size([8, 2])
# loss 1.059408187866211
# sample size torch.Size([8, 2])
# loss 1.1044167280197144
# sample size torch.Size([8, 2])
# loss 1.0886375904083252
# sample size torch.Size([8, 2])
# loss 1.0888863801956177
# sample size torch.Size([8, 2])
# loss 1.061381459236145
# sample size torch.Size([4, 2])
# loss 1.0891594886779785
# test loss 1.1029658317565918
# test loss 1.1144459247589111
# test loss 1.116646647453308
# val acc tensor(0.3000)
# epoch 2
# sample size torch.Size([8, 2])
# loss 1.0711214542388916
# sample size torch.Size([8, 2])
# loss 1.0926954746246338
# sample size torch.Size([8, 2])
# loss 1.0345555543899536
# sample size torch.Size([8, 2])
# loss 1.0569899082183838
# sample size torch.Size([8, 2])
# loss 1.1155444383621216
# sample size torch.Size([8, 2])
# loss 1.0730695724487305
# sample size torch.Size([8, 2])
# loss 1.0551862716674805
# sample size torch.Size([8, 2])
# loss 1.149111270904541
# sample size torch.Size([8, 2])
# loss 1.0876550674438477
# sample size torch.Size([8, 2])
# loss 1.1008373498916626
# sample size torch.Size([8, 2])
# loss 1.0958412885665894
# sample size torch.Size([8, 2])
# loss 1.0729308128356934
# sample size torch.Size([4, 2])
# loss 1.0573655366897583
# test loss 1.1022579669952393
# test loss 1.1139812469482422
# test loss 1.1162375211715698
# val acc tensor(0.3000)
# epoch 3
# sample size torch.Size([8, 2])
# loss 1.0802441835403442
# sample size torch.Size([8, 2])
# loss 1.071317434310913
# sample size torch.Size([8, 2])
# loss 1.0593795776367188
# sample size torch.Size([8, 2])
# loss 1.0872973203659058
# sample size torch.Size([8, 2])
# loss 1.140418291091919
# sample size torch.Size([8, 2])
# loss 1.0426945686340332
# sample size torch.Size([8, 2])
# loss 1.093636155128479
# sample size torch.Size([8, 2])
# loss 1.0607292652130127
# sample size torch.Size([8, 2])
# loss 1.1232255697250366
# sample size torch.Size([8, 2])
# loss 1.037468671798706
# sample size torch.Size([8, 2])
# loss 1.1074284315109253
# sample size torch.Size([8, 2])
# loss 1.0777844190597534
# sample size torch.Size([4, 2])
# loss 1.091439127922058
# test loss 1.1018588542938232
# test loss 1.1137219667434692
# test loss 1.1155226230621338
# val acc tensor(0.3000)
# epoch 4
# sample size torch.Size([8, 2])
# loss 1.0841660499572754
# sample size torch.Size([8, 2])
# loss 1.1013737916946411
# sample size torch.Size([8, 2])
# loss 1.0679908990859985
# sample size torch.Size([8, 2])
# loss 1.064576268196106
# sample size torch.Size([8, 2])
# loss 1.0936721563339233
# sample size torch.Size([8, 2])
# loss 1.0768344402313232
# sample size torch.Size([8, 2])
# loss 1.1247771978378296
# sample size torch.Size([8, 2])
# loss 1.0699634552001953
# sample size torch.Size([8, 2])
# loss 1.1106663942337036
# sample size torch.Size([8, 2])
# loss 1.081626296043396
# sample size torch.Size([8, 2])
# loss 1.0686266422271729
# sample size torch.Size([8, 2])
# loss 1.0495078563690186
# sample size torch.Size([4, 2])
# loss 1.072741985321045
# test loss 1.101215124130249
# test loss 1.1132725477218628
# test loss 1.1151529550552368
# val acc tensor(0.3000)
# epoch 5
# sample size torch.Size([8, 2])
# loss 1.1240980625152588
# sample size torch.Size([8, 2])
# loss 1.1009072065353394
# sample size torch.Size([8, 2])
# loss 1.0922154188156128
# sample size torch.Size([8, 2])
# loss 1.0705029964447021
# sample size torch.Size([8, 2])
# loss 1.0324714183807373
# sample size torch.Size([8, 2])
# loss 1.027205467224121
# sample size torch.Size([8, 2])
# loss 1.0842280387878418
# sample size torch.Size([8, 2])
# loss 1.0591304302215576
# sample size torch.Size([8, 2])
# loss 1.111477255821228
# sample size torch.Size([8, 2])
# loss 1.101426362991333
# sample size torch.Size([8, 2])
# loss 1.0397387742996216
# sample size torch.Size([8, 2])
# loss 1.0981945991516113
# sample size torch.Size([4, 2])
# loss 1.1711478233337402
# test loss 1.1012192964553833
# test loss 1.113209843635559
# test loss 1.1145803928375244
# val acc tensor(0.3000)
# epoch 6
# sample size torch.Size([8, 2])
# loss 1.071660041809082
# sample size torch.Size([8, 2])
# loss 1.1309657096862793
# sample size torch.Size([8, 2])
# loss 1.0522397756576538
# sample size torch.Size([8, 2])
# loss 1.097924828529358
# sample size torch.Size([8, 2])
# loss 1.0714197158813477
# sample size torch.Size([8, 2])
# loss 1.0714638233184814
# sample size torch.Size([8, 2])
# loss 1.105528712272644
# sample size torch.Size([8, 2])
# loss 1.099370002746582
# sample size torch.Size([8, 2])
# loss 1.1046299934387207
# sample size torch.Size([8, 2])
# loss 1.111976146697998
# sample size torch.Size([8, 2])
# loss 1.0698261260986328
# sample size torch.Size([8, 2])
# loss 1.0375511646270752
# sample size torch.Size([4, 2])
# loss 1.0028400421142578
# test loss 1.100714087486267
# test loss 1.1126362085342407
# test loss 1.1134684085845947
# val acc tensor(0.3000)
# epoch 7
# sample size torch.Size([8, 2])
# loss 1.1030429601669312
# sample size torch.Size([8, 2])
# loss 1.0636988878250122
# sample size torch.Size([8, 2])
# loss 1.0543688535690308
# sample size torch.Size([8, 2])
# loss 1.081459641456604
# sample size torch.Size([8, 2])
# loss 1.055318832397461
# sample size torch.Size([8, 2])
# loss 1.0370291471481323
# sample size torch.Size([8, 2])
# loss 1.0958855152130127
# sample size torch.Size([8, 2])
# loss 1.090349793434143
# sample size torch.Size([8, 2])
# loss 1.0651944875717163
# sample size torch.Size([8, 2])
# loss 1.0748600959777832
# sample size torch.Size([8, 2])
# loss 1.0813785791397095
# sample size torch.Size([8, 2])
# loss 1.1409496068954468
# sample size torch.Size([4, 2])
# loss 1.1554511785507202
# test loss 1.1004326343536377
# test loss 1.1124324798583984
# test loss 1.1133136749267578
# val acc tensor(0.3000)
# epoch 8
# sample size torch.Size([8, 2])
# loss 1.1054872274398804
# sample size torch.Size([8, 2])
# loss 1.0788748264312744
# sample size torch.Size([8, 2])
# loss 1.0502785444259644
# sample size torch.Size([8, 2])
# loss 1.0438411235809326
# sample size torch.Size([8, 2])
# loss 1.0628353357315063
# sample size torch.Size([8, 2])
# loss 1.0953282117843628
# sample size torch.Size([8, 2])
# loss 1.0615571737289429
# sample size torch.Size([8, 2])
# loss 1.1372644901275635
# sample size torch.Size([8, 2])
# loss 1.0496554374694824
# sample size torch.Size([8, 2])
# loss 1.1088879108428955
# sample size torch.Size([8, 2])
# loss 1.040787696838379
# sample size torch.Size([8, 2])
# loss 1.1580783128738403
# sample size torch.Size([4, 2])
# loss 1.0573922395706177
# test loss 1.099837064743042
# test loss 1.1123931407928467
# test loss 1.1140902042388916
# val acc tensor(0.3500)
# epoch 9
# sample size torch.Size([8, 2])
# loss 1.0926964282989502
# sample size torch.Size([8, 2])
# loss 1.0898643732070923
# sample size torch.Size([8, 2])
# loss 1.0654973983764648
# sample size torch.Size([8, 2])
# loss 1.1220885515213013
# sample size torch.Size([8, 2])
# loss 1.0991525650024414
# sample size torch.Size([8, 2])
# loss 1.0787639617919922
# sample size torch.Size([8, 2])
# loss 1.0504963397979736
# sample size torch.Size([8, 2])
# loss 1.093933343887329
# sample size torch.Size([8, 2])
# loss 1.0635676383972168
# sample size torch.Size([8, 2])
# loss 1.0569615364074707
# sample size torch.Size([8, 2])
# loss 1.0880601406097412
# sample size torch.Size([8, 2])
# loss 1.062031865119934
# sample size torch.Size([4, 2])
# loss 1.1071534156799316
# test loss 1.0996158123016357
# test loss 1.112479567527771
# test loss 1.1146961450576782
# val acc tensor(0.3500)

# %%
model2=NN()
model2.load_state_dict(torch.load("best_model.pt",weights_only=True))
# Out:
# <All keys matched successfully>
